# %% [markdown]
# # Scrapping ViableEDU's Linkedin
#
# We want to know who is interacting with viableEDU:
# * Persons reacting to content posted
# * Information about persons interacting with the posts
# * List of followers
#
# Sources:
# * https://selenium-python.readthedocs.io/

# %%
# Libraries
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import numpy as np
import pandas as pd
import re
import math as mt
from datetime import datetime

# %%
# Initialize Selenium
driver = webdriver.Chrome(executable_path='ChromeDriver/chromedriver.exe')

# %%
# Login into Linkedin
url = 'https://www.linkedin.com/login'
driver.get(url)

# Locate the elements to be filled
user = driver.find_element_by_id("username")
user.clear()
pswd = driver.find_element_by_id("password")
pswd.clear()

# Introduce your credentials
user.send_keys("")
pswd.send_keys("")
pswd.send_keys(Keys.RETURN)

# %% [markdown]
# ## Scrapping ViableEDU Linkedin

# %%
# Scrapping ViableEDU Linkedin
url2 = 'https://www.linkedin.com/company/viableedu/'
driver.get(url2)

# Scroll down the page until it reachs the end
webElem = driver.find_element_by_tag_name('html')
i = 0
while (i < 20):
    time.sleep(0.5)
    webElem.send_keys(Keys.PAGE_DOWN)
    i = i + 1

# %%
# Close the chat window
driver.find_element_by_id('ember285').click()

# %% [markdown]
# ### List of posts made by ViableEDU

# %%
# Get info from all the posts
postsList = driver.find_element_by_id('organization-feed')
posts = postsList.find_elements_by_class_name('occludable-update.ember-view')

# %%
postDF = pd.DataFrame(columns=['author','followers','dayPosted','description','interactionsTot','commentsTot','postNmbr'])
postInfo = {}
for i in range(len(posts)):
    # Who made the post
    postInfo['author'] = posts[i].find_element_by_class_name('feed-shared-actor__title').text 

    # Number of followers at the time of posting
    postInfo['followers'] = posts[i].find_element_by_class_name('feed-shared-actor__description.t-12.t-normal.t-black--light').text 

    # When it was posted
    postInfo['dayPosted'] = posts[i].find_element_by_class_name('feed-shared-actor__sub-description.t-12.t-normal.t-black--light').find_element_by_class_name('visually-hidden').text

    # Post description 
    try:
        postInfo['description'] = posts[i].find_element_by_class_name('break-words').text
    except:
        postInfo['description'] = ''        
        
    # How many reactions got the post
    n = posts[i].find_element_by_class_name('social-details-social-counts.ember-view').text.split('\n')
    if len(n) == 1:
        postInfo['interactionsTot'] = int(n[0])
        postInfo['commentsTot'] = 0
    elif 'Views' not in n[1]:
        postInfo['interactionsTot'] = int(n[0])
        postInfo['commentsTot'] = int(re.findall(r'\d+',n[1])[0])
    else:
        postInfo['interactionsTot'] = int(n[0])
        postInfo['commentsTot'] = 0
        
    # Post number (0 = most recent post)
    postInfo['postNmbr'] = i
    # Append results in dataframe
    postDF = postDF.append(pd.DataFrame.from_dict(postInfo,orient = 'index').T)

# %%
postDF['dayScrapped'] = datetime.today().strftime('%Y-%m-%d')
postDF.reset_index(inplace=True,drop=True)
postDF
# Out:
#        author     followers     dayPosted  \
# 0   ViableEdu  93 followers  16 hours ago
# 1   ViableEdu  93 followers    4 days ago
# 2   ViableEdu  93 followers    1 week ago
# 3   ViableEdu  93 followers    5 days ago
# 4   ViableEdu  93 followers    1 week ago
# 5   ViableEdu  93 followers   2 weeks ago
# 6   ViableEdu  93 followers   2 weeks ago
# 7   ViableEdu  93 followers   2 weeks ago
# 8   ViableEdu  93 followers    1 week ago
# 9   ViableEdu  93 followers   3 weeks ago
# 10  ViableEdu  93 followers   1 month ago
# 11  ViableEdu  93 followers   3 weeks ago
# 12  ViableEdu  93 followers   1 month ago
# 13  ViableEdu  93 followers   1 month ago
# 14  ViableEdu  93 followers   1 month ago
# 15  ViableEdu  93 followers  2 months ago
# 16  ViableEdu  93 followers  3 months ago
#
#                                           description interactionsTot  \
# 0   Today, Chris White and ViableEdu discussed the...              14
# 1   Chris White and ViableEdu sat down with Procli...             154
# 2   This morning, ViableEdu and Chris White broke ...              24
# 3   Today, Chris White and ViableEdu discussed the...              19
# 4   Today, ViableEdu and Chris White dug into WHY ...              22
# 5   Week #2 of our Fintech Apprentice Program kick...              15
# 6   A huge thanks to our first Coffee Chat network...              31
# 7   In the advanced session for week one of the Vi...              22
# 8   Thank you to this week's Coffee Chat networkin...              25
# 9   Extremely excited to kick off our inaugural 8-...              29
# 10  Lead instructor Chris White on our mission and...              10
# 11  This morning, Chris White and ViableEdu De-Mys...              23
# 12  Have any questions on the curriculum, structur...               7
# 13                                                                  7
# 14  Please join Chris White and Joel Brown-Christe...              39
# 15  Officially announcing the release of ViableEdu...              13
# 16                               Welcome to ViableEdu              13
#
#    commentsTot postNmbr dayScrapped
# 0            0        0  2020-11-03
# 1            9        1  2020-11-03
# 2            0        2  2020-11-03
# 3            0        3  2020-11-03
# 4            1        4  2020-11-03
# 5            0        5  2020-11-03
# 6            1        6  2020-11-03
# 7            1        7  2020-11-03
# 8            1        8  2020-11-03
# 9            0        9  2020-11-03
# 10           0       10  2020-11-03
# 11           0       11  2020-11-03
# 12           0       12  2020-11-03
# 13           0       13  2020-11-03
# 14           2       14  2020-11-03
# 15           0       15  2020-11-03
# 16           0       16  2020-11-03

# %% [markdown]
# ### List of people who react to the post

# %%
# Scroll down the page until it reachs the end
webElem = driver.find_element_by_tag_name('html')
i = 0
while (i < 20):
    time.sleep(0.5)
    webElem.send_keys(Keys.PAGE_UP)
    i = i + 1

# %%
likesDF = pd.DataFrame(columns=['name','jobTitle','linkedin','reaction','postNmbr'])
for j in range(len(posts)):
    time.sleep(0.5)
    # Open the window with list of reactions
    posts[j].find_element_by_class_name('reactions-icon.social-detail-social-counts__count-icon.reactions-icon__consumption--small').click()    
    time.sleep(0.5)
    # Scrolldown to show the whole list of reactions
    webElem = driver.find_element_by_xpath('//div[@class="artdeco-modal__content social-details-reactors-modal__content ember-view"]//a')
    n = postInfo['interactionsTot']
    x = 0
    while (x < mt.ceil(n/6)):
        time.sleep(0.5)
        webElem.send_keys(Keys.PAGE_DOWN)
        x = x + 1
    
    # Scrape the list of people
    peopleInteracting = driver.find_elements_by_class_name('artdeco-list__item')
    peopleDF = pd.DataFrame(columns=['name','jobTitle','linkedin','reaction','postNmbr'])
    peopleDict = {}
    time.sleep(0.5)
    
    # Loop to collect all the info
    for i in range(n):
        # Post number (0 = most recent post)
        peopleDict['postNmbr'] = j
        
        # Name
        try:
            peopleDict['name'] = peopleInteracting[i].find_element_by_class_name('artdeco-entity-lockup__title.ember-view').text
        except:
            peopleDict['name'] = ''

        # Job title
        try:
            peopleDict['jobTitle'] = peopleInteracting[i].find_element_by_class_name('artdeco-entity-lockup__caption.ember-view').text
        except:
            peopleDict['jobTitle'] = ''

        # Linkedin Link
        try:
            peopleDict['linkedin'] = peopleInteracting[i].find_element_by_class_name('link-without-hover-state.ember-view').get_attribute('href')
        except:
            peopleDict['linkedin'] = ''

        # Reaction to the post
        try:
            peopleDict['reaction'] = peopleInteracting[i].find_element_by_class_name('reactions-icon.social-details-reactors-tab-body__icon.reactions-icon__consumption--small').get_attribute('alt')
        except:
            peopleDict['reaction'] = ''
        
        peopleDF = peopleDF.append(pd.DataFrame.from_dict(peopleDict,orient = 'index').T)
    likesDF = likesDF.append(peopleDF)
    # Click close
    driver.find_element_by_class_name("artdeco-modal__dismiss.artdeco-button.artdeco-button--circle.artdeco-button--muted.artdeco-button--2.artdeco-button--tertiary.ember-view").click()

# %%
likesDF.reset_index(inplace=True,drop=True)
likesDF
# Out:
#                        name  \
# 0    Joel Brown-Christenson
# 1              Joshua Watts
# 2             Reese Gregory
# 3               Chris White
# 4            Justin Hartwig
# ..                      ...
# 216              David Wang
# 217            Christine Ji
# 218         Larkin Ison III
# 219           James Justicz
# 220         Margaret Koulen
#
#                                               jobTitle  \
# 0       Director of Business Development at ViableMkts
# 1                  Student-Athlete at Brown University
# 2    Founder of RWG Software Designs | FinTech Appr...
# 3                         CEO at ViableMkts & BondCliQ
# 4                       Williams College Class of 2025
# ..                                                 ...
# 216          Junior Developer (Consultant) at BondCliQ
# 217    Women's Advisory Program at RBC Capital Markets
# 218                 Business Analyst at ViableMkts LLC
# 219                       Viable360 Consulting Analyst
# 220                    Part-Time Associate at OpenDoor
#
#                                               linkedin reaction postNmbr
# 0    https://www.linkedin.com/in/joel-brown-christe...     LIKE        0
# 1    https://www.linkedin.com/in/joshuawatts13?mini...     LIKE        0
# 2    https://www.linkedin.com/in/reese-gregory-4735...     LIKE        0
# 3    https://www.linkedin.com/in/chris-white-bb3923...     LIKE        0
# 4    https://www.linkedin.com/in/justin-hartwig-a53...     LIKE        0
# ..                                                 ...      ...      ...
# 216  https://www.linkedin.com/in/david-wang-b07a661...     LIKE       16
# 217  https://www.linkedin.com/in/christine-ji?miniP...     LIKE       16
# 218  https://www.linkedin.com/in/larkin-ison-iii-19...     LIKE       16
# 219  https://www.linkedin.com/in/james-justicz-2972...     LIKE       16
# 220  https://www.linkedin.com/in/margaret-koulen-a8...     LIKE       16
#
# [221 rows x 5 columns]

# %%
# We get the list
personsOfInterest = likesDF.drop_duplicates('name').reset_index(drop = True)
personsOfInterest = personsOfInterest[['name','jobTitle','linkedin']]
personsOfInterest
# Out:
#                       name                                           jobTitle  \
# 0   Joel Brown-Christenson     Director of Business Development at ViableMkts
# 1             Joshua Watts                Student-Athlete at Brown University
# 2            Reese Gregory  Founder of RWG Software Designs | FinTech Appr...
# 3              Chris White                       CEO at ViableMkts & BondCliQ
# 4           Justin Hartwig                     Williams College Class of 2025
# ..                     ...                                                ...
# 57         Margaret Koulen                    Part-Time Associate at OpenDoor
# 58       Jay Baker-Johnson              MBA Candidate at Villanova University
# 59            Katherine Hu                                   Intern at FinTEx
# 60                 Jenn Lu  Intern at Georgetown University Investment Office
# 61              David Wang          Junior Developer (Consultant) at BondCliQ
#
#                                              linkedin
# 0   https://www.linkedin.com/in/joel-brown-christe...
# 1   https://www.linkedin.com/in/joshuawatts13?mini...
# 2   https://www.linkedin.com/in/reese-gregory-4735...
# 3   https://www.linkedin.com/in/chris-white-bb3923...
# 4   https://www.linkedin.com/in/justin-hartwig-a53...
# ..                                                ...
# 57  https://www.linkedin.com/in/margaret-koulen-a8...
# 58  https://www.linkedin.com/in/jaybakerjohnson?mi...
# 59  https://www.linkedin.com/in/katherine-hu-123b0...
# 60  https://www.linkedin.com/in/jenn-lu-b05969164?...
# 61  https://www.linkedin.com/in/david-wang-b07a661...
#
# [62 rows x 3 columns]

# %% [markdown]
# ### List of Linkedin followers

# %%
# Open the window with list of followers
url3 = 'https://www.linkedin.com/company/67245387/admin/analytics/followers/?anchor=org-view-followers'
driver.get(url3)
driver.find_element_by_class_name('org-view-page-followers-module__modal-button.t-16.p1.t-bold.full-width').click()

# %%
# Scrolldown to show the whole list of reactions
webElem = driver.find_element_by_xpath('//div[@id="ember459"]//a')
n = int(re.findall(r'\d+',postDF.loc[0,'followers'])[0])
x = 0
while (x < mt.ceil(n/6)):
    time.sleep(0.5)
    webElem.send_keys(Keys.PAGE_DOWN)
    x = x + 1

# %%
# Download all the list
followersList = driver.find_elements_by_css_selector('#ember459 > table > tbody > tr')

followersDF = pd.DataFrame(columns=['name','linkedin','jobTitle','monthFollowed'])
followers = {}
for i in range(len(followersList)):
    time.sleep(1)
    try:
        followers['name'] = followersList[i].find_element_by_class_name('artdeco-entity-lockup__title.ember-view').text
    except:
        followers['name'] = ''

    try:
        followers['linkedin'] = followersList[i].find_element_by_class_name('ember-view.link-without-hover-visited').get_attribute('href')
    except:
        followers['linkedin'] = ''

    try:
        followers['jobTitle'] = followersList[i].find_element_by_class_name('artdeco-entity-lockup__caption.ember-view').text
    except:
        followers['jobTitle'] = ''

    try:
        followers['monthFollowed'] = followersList[i].find_element_by_class_name('t-14.t-black--light').text.split('\n')[0]
    except:
        followers['monthFollowed'] = ''
    followersDF = followersDF.append(pd.DataFrame.from_dict(followers,orient = 'index').T)

# %%
followersDF.reset_index(inplace=True,drop=True)
followersDF
# Out:
#                        name  \
# 0              David Holden
# 1          Larkin Ison, Jr.
# 2                Brian Lane
# 3         Timothy Oberweger
# 4   Michael Jordan Pilgreen
# ..                      ...
# 88     Eamon Garrity-Rokous
# 89            James Justicz
# 90          Margaret Koulen
# 91             Jamie Kaplan
# 92   Joel Brown-Christenson
#
#                                              linkedin  \
# 0   https://www.linkedin.com/in/david-holden-41469...
# 1         https://www.linkedin.com/in/larkin-ison-jr/
# 2             https://www.linkedin.com/in/brianjlane/
# 3             https://www.linkedin.com/in/ilovetitle/
# 4   https://www.linkedin.com/in/michael-jordan-pil...
# ..                                                ...
# 88  https://www.linkedin.com/in/eamon-garrity-roko...
# 89  https://www.linkedin.com/in/james-justicz-2972...
# 90  https://www.linkedin.com/in/margaret-koulen-a8...
# 91  https://www.linkedin.com/in/jamie-kaplan-169b9...
# 92  https://www.linkedin.com/in/joel-brown-christe...
#
#                                              jobTitle  monthFollowed
# 0               Student at The University of Michigan  November 2020
# 1            Business Units Techical Training Manager  November 2020
# 2                            Founder & CEO at FixtHub   October 2020
# 3   Vice President, Sr. Business Development Offic...   October 2020
# 4        Multi-Disciplined Wealth Advisor and Analyst   October 2020
# ..                                                ...            ...
# 88  Consulting Business Analyst at ViableMkts LLC ...    August 2020
# 89                       Viable360 Consulting Analyst    August 2020
# 90                    Part-Time Associate at OpenDoor    August 2020
# 91                              BondCliQ & ViableMkts    August 2020
# 92     Director of Business Development at ViableMkts    August 2020
#
# [93 rows x 4 columns]

# %% [markdown]
# ### Join between followers list and people who react to our posts

# %%
fullList = followersDF.append(personsOfInterest)
fullList.drop_duplicates('name',inplace = True)
fullList.reset_index(drop = True,inplace = True)
fullList
# Out:
#                         name  \
# 0               David Holden
# 1           Larkin Ison, Jr.
# 2                 Brian Lane
# 3          Timothy Oberweger
# 4    Michael Jordan Pilgreen
# ..                       ...
# 109                 Emeka O.
# 110             Daniel Green
# 111            Kanani Briggs
# 112     Tracy Robinton Huser
# 113     Daniel Comiskey, CFA
#
#                                               linkedin  \
# 0    https://www.linkedin.com/in/david-holden-41469...
# 1          https://www.linkedin.com/in/larkin-ison-jr/
# 2              https://www.linkedin.com/in/brianjlane/
# 3              https://www.linkedin.com/in/ilovetitle/
# 4    https://www.linkedin.com/in/michael-jordan-pil...
# ..                                                 ...
# 109  https://www.linkedin.com/in/emekaogbonnna?mini...
# 110  https://www.linkedin.com/in/daniel-green-a5468...
# 111  https://www.linkedin.com/in/kananibriggs?miniP...
# 112  https://www.linkedin.com/in/tracy-robinton-hus...
# 113  https://www.linkedin.com/in/daniel-comiskey-cf...
#
#                                               jobTitle  monthFollowed
# 0                Student at The University of Michigan  November 2020
# 1             Business Units Techical Training Manager  November 2020
# 2                             Founder & CEO at FixtHub   October 2020
# 3    Vice President, Sr. Business Development Offic...   October 2020
# 4         Multi-Disciplined Wealth Advisor and Analyst   October 2020
# ..                                                 ...            ...
# 109                   Helping Brands Accelerate Growth            NaN
# 110              Customer Success Manager at DeepCrawl            NaN
# 111  Agent Partner at The Curtin Team - Building we...            NaN
# 112                               Director at VIVALDI_            NaN
# 113  Senior Investment Product Analyst at Income Re...            NaN
#
# [114 rows x 4 columns]

# %% [markdown]
# ### Scrape informatio from each Linkedin profile

# %%
# To be done
